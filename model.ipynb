# %%
hc = [
    'what is the role of a primary care physician',
    'how do vaccines work in our body',
    'how does a healthy diet impact your overall health',
    'what is the best way to maintain a healthy weight',
    'can you explain the different types of health insurance plans',
    'what are the benefits of regular exercise',
    'how does stress affect the body',
    'how often should i get a general health checkup',
    'how important is sleep for health',
    'what are the common symptoms of diabetes',
    'can you explain the health risks of obesity',
    'what is telemedicine',
    'how does mental health affect physical health',
    'what are some ways to prevent heart disease',
    'can you explain the concept of herd immunity',
    'what are the most common mental health disorders',
    'how does smoking affect the lungs',
    'what are the health risks of high cholesterol',
    'what is the difference between type one and type two diabetes',
    'can you explain the health benefits of yoga',
    'what is the role of genetics in health',
    'what are the early signs of alzheimers disease',
    'how can i protect my skin from the sun',
    'how does hypertension affect the body',
    'what are some strategies for managing chronic pain',
    'what is the human microbiome and how does it affect health',
    'what is the role of the world health organization',
    'how can diet affect mental health',
    'what are the early symptoms of parkinsons disease',
    'can you explain the different types of cancer',
    'how important is early detection in cancer',
    'what is the connection between gut health and mood',
    'what is the effect of climate change on health',
    'what are the benefits of breastfeeding',
    'how can a pregnant woman ensure the health of her baby',
    'what are the health risks of alcohol consumption',
    'what are the symptoms of a stroke',
    'how is hiv transmitted',
    'what are some preventive measures against the common cold',
    'how can i improve my dental health',
    'what are the benefits of regular eye checkups',
    'what is osteoporosis and how can it be prevented',
    'what are the risk factors for heart disease',
    'what are the symptoms of a heart attack in women',
    'how can i increase my bone density',
    'what is palliative care',
    'what are the common causes of hair loss',
    'what is the role of antioxidants in health',
    'how does air pollution affect our health',
    'what are some strategies to quit smoking',
    'how does regular physical activity benefit mental health',
    'what is the difference between a dietitian and a nutritionist',
    'how is autism diagnosed',
    'how can you manage the symptoms of adhd',
    'what are the health benefits of drinking water',
    'how does exposure to secondhand smoke affect health',
    'what are the symptoms of lung cancer',
    'what is the role of probiotics in gut health',
    'how does menopause affect a womans health',
    'what are the health benefits of green tea',
    'what is the function of the liver in the human body',
    'what are the early signs of liver disease',
    'what is the impact of high blood sugar levels',
    'how is depression diagnosed and treated',
    'what is the difference between dementia and alzheimers',
    'how can lifestyle changes help manage type two diabetes',
    'what is bipolar disorder',
    'what is the difference between an allergy and an intolerance'
]

nhc = [
    'what is the capital of australia',
    'who wrote the book pride and prejudice',
    'what is the tallest mountain in the world',
    'how deep is the mariana trench',
    'what is the speed of light',
    'who painted the mona lisa',
    'what is quantum physics',
    'who is the current president of the united states',
    'how old is the earth',
    'what is the largest planet in our solar system',
    'who won the oscar for best picture in 2020',
    'what is the longest river in the world',
    'who discovered penicillin',
    'what is the square root of 144',
    'what is the largest ocean in the world',
    'how far is the moon from the earth',
    'who invented the telephone',
    'what is the population of china',
    'how many countries are there in the world',
    'who composed the fifth symphony',
    'what is the tallest building in the world',
    'what is the chemical formula for water',
    'who is the richest person in the world',
    'what is the highest waterfall in the world',
    'who is the current prime minister of the united kingdom',
    'what is the largest country by land area',
    'what is the fastest animal on land',
    'who directed the movie titanic',
    'how old is the universe',
    'what is the hottest planet in our solar system',
    'who won the world cup in soccer in 2018',
    'what is the capital of canada',
    'who wrote the novel 1984',
    'what is the theory of relativity',
    'who is the current secretary general of the united nations',
    'how old is the great wall of china',
    'what is the smallest planet in our solar system',
    'who painted the starry night',
    'what is the boiling point of water at sea level',
    'who is the current chancellor of germany',
    'how long is the amazon river',
    'who discovered gravity',
    'what is the cube root of 27',
    'what is the smallest ocean in the world',
    'how far is the sun from the earth',
    'who invented the light bulb',
    'what is the population of india',
    'how many states are there in the united states',
    'who composed the magic flute',
    'what is the longest bridge in the world',
    'what is the chemical formula for carbon dioxide',
    'who is the current queen of the united kingdom'
]

words = [
    "abdomen",
    "acute",
    "admission",
    "adrenal",
    "adverse",
    "aerobic",
    "aids",
    "allergy",
    "ambulatory",
    "amino",
    "analgesia",
    "anemia",
    "anesthesia",
    "angiography",
    "antibiotic",
    "antibody",
    "antigen",
    "anxiety",
    "aorta",
    "appendix",
    "artery",
    "arthritis",
    "aspirin",
    "asthma",
    "atherosclerosis",
    "atrium",
    "bacteria",
    "benign",
    "biopsy",
    "bladder",
    "bleeding",
    "blood",
    "bone",
    "brain",
    "breathing",
    "bronchitis",
    "calcium",
    "cancer",
    "capillary",
    "carbohydrate",
    "cardiology",
    "cardiovascular",
    "cataract",
    "catheter",
    "cell",
    "cholesterol",
    "chronic",
    "cirrhosis",
    "clotting",
    "collagen",
    "coma",
    "congenital",
    "congestive",
    "contagious",
    "contraction",
    "coronary",
    "cortex",
    "cyst",
    "deficiency",
    "dehydration",
    "dementia",
    "dental",
    "depression",
    "dermatology",
    "diabetes",
    "diagnosis",
    "dialysis",
    "diarrhea",
    "dietary",
    "digestion",
    "disease",
    "disorder",
    "diuretic",
    "dna",
    "dysfunction",
    "eczema",
    "edema",
    "electrolyte",
    "embolism",
    "endocrine",
    "enzyme",
    "epidemiology",
    "epilepsy",
    "erectile",
    "erythrocyte",
    "estrogen",
    "etiology",
    "examination",
    "exercise",
    "fatigue",
    "fatty",
    "fever",
    "fibrosis",
    "fracture",
    "gastric",
    "gastroenterology",
    "gene",
    "genetic",
    "gland",
    "glaucoma",
    "glucose",
    "gynecology",
    "hallucination",
    "headache",
    "healing",
    "health",
    "heart",
    "hematology",
    "hemoglobin",
    "hepatitis",
    "hereditary",
    "hernia",
    "herpes",
    "hormone",
    "hospital",
    "hyperlipidemia",
    "hypertension",
    "immunity",
    "infection",
    "inflammation",
    "influenza",
    "injection",
    "insomnia",
    "insulin",
    "intestine",
    "intravenous",
    "jaundice",
    "joint",
    "kidney",
    "laboratory",
    "lactose",
    "lesion",
    "leukemia",
    "leukocyte",
    "lipid",
    "liver",
    "lung",
    "lymph",
    "magnetic",
    "malignant",
    "mammography",
    "medication",
    "melanoma",
    "meningitis",
    "menopause",
    "metabolism",
    "metastasis",
    "microorganism",
    "microscope",
    "migraine",
    "mineral",
    "molecule",
    "monitoring",
    "mortality",
    "muscle",
    "myocardium",
    "narcotic",
    "nephrology",
    "nerve",
    "neurology",
    "neurotransmitter",
    "nutrition",
    "obesity",
    "oncology",
    "opiate",
    "ophthalmology",
    "organ",
    "osteoporosis",
    "otolaryngology",
    "ovary",
    "oxygen",
    "pain",
    "palliative",
    "pancreas",
    "paralysis",
    "parasite",
    "pathology",
    "patient",
    "pediatric",
    "peptic",
    "pharmacology",
    "pharmacy",
    "physician",
    "physiology",
    "pneumonia",
    "poison",
    "polyp",
    "pregnancy",
    "prescription",
    "prevention",
    "protein",
    "psychiatry",
    "psychosis",
    "pulse",
    "radiation",
    "radiology",
    "receptor",
    "recovery",
    "rehabilitation",
    "respiration",
    "rheumatology",
    "sarcoma",
    "schizophrenia",
    "sclerosis",
    "screening",
    "seizure",
    "sepsis",
    "surgery",
    "symptom",
    "syndrome",
    "synthesis",
    "therapy",
    "thrombosis",
    "thyroid",
    "tissue",
    "toxicology",
    "transplant",
    "trauma",
    "treatment",
    "tumor",
    "ulcer",
    "ultrasound",
    "urinary",
    "vaccine",
    "vein",
    "virus",
    "vitamin",
    "xray",
    "yeast",
    "zinc"
]

# %% [markdown]
# Steps to pre process
# 1. Find a standard training dictionary of 10,000 words plus probably 100-500 medical words or possibly just the medical words
# 2. Convert each sentence into a vector

# %%
y = [0 for i in range(0, len(hc)+len(nhc))]
x = hc + nhc
for i in range(0, len(hc)):
    y[i] = 1
    
def vectorize(x):
    vector = [0 for i in range(0, len(words))]
    for i in range(0, len(words)):
        if (words[i] in x) or (words[i]+"s" in x) or (words[i]+"es" in x) or (words[i]+"ed" in x) or (words[i]+"ing" in x):
            vector[i] = 1
    return vector

x_vectorize = [vectorize(x[i]) for i in range(0, len(x))]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_vectorize, y, test_size=0.33, random_state=42)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(len(words),)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

X_train_true = X_train[:int(len(X_train)/1.3)]
X_train_val = X_train[int(len(X_train)/1.3):]
y_train_true = y_train[:int(len(y_train)/1.3)]
y_train_val = y_train[int(len(y_train)/1.3):]


history = model.fit(X_train_true,
                    y_train_true,
                    epochs=100,
                    batch_size=32,
                    validation_data=(X_train_val, y_train_val))
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 118ms/step - loss: 0.6916 - accuracy: 0.5574 - val_loss: 0.6935 - val_accuracy: 0.2632
# Epoch 2/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6852 - accuracy: 0.5574 - val_loss: 0.6932 - val_accuracy: 0.3684
# Epoch 3/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6810 - accuracy: 0.5902 - val_loss: 0.6918 - val_accuracy: 0.3684
# Epoch 4/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6779 - accuracy: 0.5902 - val_loss: 0.6911 - val_accuracy: 0.3684
# Epoch 5/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6747 - accuracy: 0.5902 - val_loss: 0.6912 - val_accuracy: 0.3684
# Epoch 6/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6722 - accuracy: 0.5902 - val_loss: 0.6904 - val_accuracy: 0.3684
# Epoch 7/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6698 - accuracy: 0.5902 - val_loss: 0.6899 - val_accuracy: 0.3684
# Epoch 8/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6674 - accuracy: 0.5902 - val_loss: 0.6897 - val_accuracy: 0.3684
# Epoch 9/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6651 - accuracy: 0.5902 - val_loss: 0.6897 - val_accuracy: 0.3684
# Epoch 10/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6630 - accuracy: 0.5902 - val_loss: 0.6891 - val_accuracy: 0.3684
# Epoch 11/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6606 - accuracy: 0.5902 - val_loss: 0.6888 - val_accuracy: 0.3684
# Epoch 12/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6584 - accuracy: 0.5902 - val_loss: 0.6883 - val_accuracy: 0.3684
# Epoch 13/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6564 - accuracy: 0.5902 - val_loss: 0.6885 - val_accuracy: 0.3684
# Epoch 14/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6539 - accuracy: 0.5902 - val_loss: 0.6879 - val_accuracy: 0.3684
# Epoch 15/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6516 - accuracy: 0.5902 - val_loss: 0.6874 - val_accuracy: 0.3684
# Epoch 16/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6494 - accuracy: 0.5902 - val_loss: 0.6866 - val_accuracy: 0.3684
# Epoch 17/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6472 - accuracy: 0.5902 - val_loss: 0.6868 - val_accuracy: 0.3684
# Epoch 18/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6449 - accuracy: 0.5902 - val_loss: 0.6858 - val_accuracy: 0.3684
# Epoch 19/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6426 - accuracy: 0.5902 - val_loss: 0.6854 - val_accuracy: 0.3684
# Epoch 20/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6404 - accuracy: 0.5902 - val_loss: 0.6852 - val_accuracy: 0.3684
# Epoch 21/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6380 - accuracy: 0.5902 - val_loss: 0.6846 - val_accuracy: 0.3684
# Epoch 22/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6358 - accuracy: 0.5902 - val_loss: 0.6845 - val_accuracy: 0.3684
# Epoch 23/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6333 - accuracy: 0.5902 - val_loss: 0.6841 - val_accuracy: 0.3684
# Epoch 24/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6311 - accuracy: 0.5902 - val_loss: 0.6835 - val_accuracy: 0.3684
# Epoch 25/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6283 - accuracy: 0.5902 - val_loss: 0.6825 - val_accuracy: 0.3684
# Epoch 26/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6259 - accuracy: 0.5902 - val_loss: 0.6817 - val_accuracy: 0.3684
# Epoch 27/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6236 - accuracy: 0.5902 - val_loss: 0.6808 - val_accuracy: 0.3684
# Epoch 28/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.6210 - accuracy: 0.5902 - val_loss: 0.6809 - val_accuracy: 0.3684
# Epoch 29/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6185 - accuracy: 0.5902 - val_loss: 0.6795 - val_accuracy: 0.3684
# Epoch 30/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6158 - accuracy: 0.5902 - val_loss: 0.6792 - val_accuracy: 0.3684
# Epoch 31/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6136 - accuracy: 0.5902 - val_loss: 0.6774 - val_accuracy: 0.3684
# Epoch 32/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6106 - accuracy: 0.5902 - val_loss: 0.6780 - val_accuracy: 0.3684
# Epoch 33/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6080 - accuracy: 0.5902 - val_loss: 0.6762 - val_accuracy: 0.3684
# Epoch 34/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6053 - accuracy: 0.5902 - val_loss: 0.6753 - val_accuracy: 0.3684
# Epoch 35/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.6025 - accuracy: 0.5902 - val_loss: 0.6740 - val_accuracy: 0.3684
# Epoch 36/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.5999 - accuracy: 0.5902 - val_loss: 0.6738 - val_accuracy: 0.3684
# Epoch 37/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5969 - accuracy: 0.5902 - val_loss: 0.6719 - val_accuracy: 0.3684
# Epoch 38/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5941 - accuracy: 0.5902 - val_loss: 0.6717 - val_accuracy: 0.3684
# Epoch 39/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5911 - accuracy: 0.5902 - val_loss: 0.6693 - val_accuracy: 0.3684
# Epoch 40/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5882 - accuracy: 0.5902 - val_loss: 0.6687 - val_accuracy: 0.3684
# Epoch 41/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5852 - accuracy: 0.5902 - val_loss: 0.6666 - val_accuracy: 0.3684
# Epoch 42/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5823 - accuracy: 0.5902 - val_loss: 0.6651 - val_accuracy: 0.3684
# Epoch 43/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5794 - accuracy: 0.5902 - val_loss: 0.6637 - val_accuracy: 0.3684
# Epoch 44/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5762 - accuracy: 0.5902 - val_loss: 0.6635 - val_accuracy: 0.3684
# Epoch 45/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5730 - accuracy: 0.5902 - val_loss: 0.6610 - val_accuracy: 0.3684
# Epoch 46/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5704 - accuracy: 0.5902 - val_loss: 0.6609 - val_accuracy: 0.3684
# Epoch 47/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5670 - accuracy: 0.5902 - val_loss: 0.6582 - val_accuracy: 0.3684
# Epoch 48/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5638 - accuracy: 0.5902 - val_loss: 0.6573 - val_accuracy: 0.3684
# Epoch 49/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5606 - accuracy: 0.5902 - val_loss: 0.6549 - val_accuracy: 0.3684
# Epoch 50/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.5575 - accuracy: 0.5902 - val_loss: 0.6534 - val_accuracy: 0.3684
# Epoch 51/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5546 - accuracy: 0.5902 - val_loss: 0.6517 - val_accuracy: 0.3684
# Epoch 52/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5513 - accuracy: 0.5902 - val_loss: 0.6502 - val_accuracy: 0.3684
# Epoch 53/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5484 - accuracy: 0.5902 - val_loss: 0.6482 - val_accuracy: 0.3684
# Epoch 54/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5454 - accuracy: 0.5902 - val_loss: 0.6468 - val_accuracy: 0.3684
# Epoch 55/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5426 - accuracy: 0.5902 - val_loss: 0.6454 - val_accuracy: 0.3684
# Epoch 56/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5389 - accuracy: 0.5902 - val_loss: 0.6435 - val_accuracy: 0.3684
# Epoch 57/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.5353 - accuracy: 0.5902 - val_loss: 0.6421 - val_accuracy: 0.3684
# Epoch 58/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5321 - accuracy: 0.5902 - val_loss: 0.6405 - val_accuracy: 0.3684
# Epoch 59/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5290 - accuracy: 0.5902 - val_loss: 0.6385 - val_accuracy: 0.3684
# Epoch 60/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5259 - accuracy: 0.5902 - val_loss: 0.6379 - val_accuracy: 0.3684
# Epoch 61/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5222 - accuracy: 0.5902 - val_loss: 0.6359 - val_accuracy: 0.3684
# Epoch 62/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5187 - accuracy: 0.5902 - val_loss: 0.6330 - val_accuracy: 0.3684
# Epoch 63/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5158 - accuracy: 0.5902 - val_loss: 0.6316 - val_accuracy: 0.3684
# Epoch 64/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.5123 - accuracy: 0.5902 - val_loss: 0.6305 - val_accuracy: 0.3684
# Epoch 65/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5086 - accuracy: 0.5902 - val_loss: 0.6287 - val_accuracy: 0.3684
# Epoch 66/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.5059 - accuracy: 0.5902 - val_loss: 0.6272 - val_accuracy: 0.3684
# Epoch 67/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.5018 - accuracy: 0.5902 - val_loss: 0.6237 - val_accuracy: 0.3684
# Epoch 68/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4984 - accuracy: 0.5902 - val_loss: 0.6214 - val_accuracy: 0.3684
# Epoch 69/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4946 - accuracy: 0.5902 - val_loss: 0.6191 - val_accuracy: 0.3684
# Epoch 70/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4908 - accuracy: 0.5902 - val_loss: 0.6179 - val_accuracy: 0.3684
# Epoch 71/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.4871 - accuracy: 0.5902 - val_loss: 0.6148 - val_accuracy: 0.3684
# Epoch 72/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4831 - accuracy: 0.5902 - val_loss: 0.6121 - val_accuracy: 0.3684
# Epoch 73/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4796 - accuracy: 0.6066 - val_loss: 0.6102 - val_accuracy: 0.3684
# Epoch 74/100
# 2/2 [==============================] - 0s 26ms/step - loss: 0.4761 - accuracy: 0.6066 - val_loss: 0.6087 - val_accuracy: 0.3684
# Epoch 75/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4724 - accuracy: 0.6066 - val_loss: 0.6061 - val_accuracy: 0.3684
# Epoch 76/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4689 - accuracy: 0.6066 - val_loss: 0.6031 - val_accuracy: 0.3684
# Epoch 77/100
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4656 - accuracy: 0.6066 - val_loss: 0.6006 - val_accuracy: 0.3684
# Epoch 78/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4623 - accuracy: 0.6721 - val_loss: 0.5990 - val_accuracy: 0.9474
# Epoch 79/100
# 2/2 [==============================] - 0s 44ms/step - loss: 0.4589 - accuracy: 0.8852 - val_loss: 0.5974 - val_accuracy: 0.9474
# Epoch 80/100
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4555 - accuracy: 0.8852 - val_loss: 0.5951 - val_accuracy: 0.9474
# Epoch 81/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4529 - accuracy: 0.8852 - val_loss: 0.5937 - val_accuracy: 0.9474
# Epoch 82/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4499 - accuracy: 0.8852 - val_loss: 0.5915 - val_accuracy: 0.9474
# Epoch 83/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4462 - accuracy: 0.8852 - val_loss: 0.5897 - val_accuracy: 0.9474
# Epoch 84/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4432 - accuracy: 0.8852 - val_loss: 0.5881 - val_accuracy: 0.9474
# Epoch 85/100
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4403 - accuracy: 0.8852 - val_loss: 0.5865 - val_accuracy: 0.9474
# Epoch 86/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4372 - accuracy: 0.8852 - val_loss: 0.5853 - val_accuracy: 0.9474
# Epoch 87/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4349 - accuracy: 0.8852 - val_loss: 0.5827 - val_accuracy: 0.9474
# Epoch 88/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4314 - accuracy: 0.8852 - val_loss: 0.5813 - val_accuracy: 0.9474
# Epoch 89/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4289 - accuracy: 0.8852 - val_loss: 0.5798 - val_accuracy: 0.9474
# Epoch 90/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4264 - accuracy: 0.8852 - val_loss: 0.5785 - val_accuracy: 0.9474
# Epoch 91/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4240 - accuracy: 0.8852 - val_loss: 0.5764 - val_accuracy: 0.9474
# Epoch 92/100
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4207 - accuracy: 0.8852 - val_loss: 0.5748 - val_accuracy: 0.9474
# Epoch 93/100
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4180 - accuracy: 0.8852 - val_loss: 0.5740 - val_accuracy: 0.9474
# Epoch 94/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4156 - accuracy: 0.8852 - val_loss: 0.5723 - val_accuracy: 0.9474
# Epoch 95/100
# 2/2 [==============================] - 0s 28ms/step - loss: 0.4131 - accuracy: 0.8852 - val_loss: 0.5718 - val_accuracy: 0.9474
# Epoch 96/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4105 - accuracy: 0.8852 - val_loss: 0.5715 - val_accuracy: 0.9474
# Epoch 97/100
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4083 - accuracy: 0.8852 - val_loss: 0.5684 - val_accuracy: 0.9474
# Epoch 98/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4057 - accuracy: 0.8852 - val_loss: 0.5670 - val_accuracy: 0.9474
# Epoch 99/100
# 2/2 [==============================] - 0s 29ms/step - loss: 0.4034 - accuracy: 0.8852 - val_loss: 0.5659 - val_accuracy: 0.9474
# Epoch 100/100
# 2/2 [==============================] - 0s 27ms/step - loss: 0.4012 - accuracy: 0.8852 - val_loss: 0.5652 - val_accuracy: 0.9474

# %%
# history_dict = history.history
# history_dict.keys()
# import matplotlib.pyplot as plt
# history_dict = history.history
# loss_values = history_dict['loss']
# val_loss_values = history_dict['val_loss']
# epochs = range(1, len(loss_values) + 1)
# plt.plot(epochs, loss_values, 'bo', label='Training loss')
# plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
# plt.title('Training and validation loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# plt.show()

# %%
# plt.clf()
# acc_values = history_dict['accuracy']
# val_acc_values = history_dict['val_accuracy']
# plt.plot(epochs, acc_values, 'bo', label='Training accuracy')
# plt.plot(epochs, val_acc_values, 'b', label='Validation accuracy')
# plt.title('Training and validation accuracy')
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.legend()
# plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4643 - accuracy: 0.8750
# [0.4643181264400482, 0.875]
